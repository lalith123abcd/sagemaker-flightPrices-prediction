# %%
import os

import numpy as np

import pandas as pd

from sklearn.model_selection import train_test_split

# %%
PROJECT_DIR = r"C:\Users\lalith Kumar\Desktop\Flights-sagemaker-project"
DATA_DIR = "data"

# %%
def get_data(name):
    file_name= f"{name}.csv"
    file_path= os.path.join(PROJECT_DIR,DATA_DIR,file_name)
    return pd.read_csv(file_path)

# %%
flights=get_data("flight_price")
flights
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
flights.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  str
#  1   Date_of_Journey  10683 non-null  str
#  2   Source           10683 non-null  str
#  3   Destination      10683 non-null  str
#  4   Route            10682 non-null  str
#  5   Dep_Time         10683 non-null  str
#  6   Arrival_Time     10683 non-null  str
#  7   Duration         10683 non-null  str
#  8   Total_Stops      10682 non-null  str
#  9   Additional_Info  10683 non-null  str
#  10  Price            10683 non-null  int64
# dtypes: int64(1), str(10)
# memory usage: 1.8 MB

# %%
flights.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %% [markdown]
# flights.dtypes

# %%
value=flights.Date_of_Journey.iloc[5]
value

# %%
value=flights.Arrival_Time.iloc[5]
value
# Out:
# '11:25'

# %% [markdown]
# CHECK FOR DUPLICATES

# %%
flights.duplicated().sum()
# Out:
# 220

# %%
(
    flights.
    loc[flights.duplicated(keep=False)]
    .sort_values(["Airline","Date_of_Journey","Source","Destination"])
    
)
# Out:
#         Airline Date_of_Journey    Source Destination                  Route  \
# 6321  Air India      01/03/2019  Banglore   New Delhi  BLR → BOM → AMD → DEL
# 9848  Air India      01/03/2019  Banglore   New Delhi  BLR → BOM → AMD → DEL
# 572   Air India      03/03/2019  Banglore   New Delhi              BLR → DEL
# 8168  Air India      03/03/2019  Banglore   New Delhi              BLR → DEL
# 1495  Air India       1/04/2019   Kolkata    Banglore  CCU → DEL → COK → BLR
# ...         ...             ...       ...         ...                    ...
# 2692   SpiceJet      24/03/2019  Banglore   New Delhi              BLR → DEL
# 2870   SpiceJet      24/03/2019  Banglore   New Delhi              BLR → DEL
# 3711   SpiceJet      24/03/2019  Banglore   New Delhi              BLR → DEL
# 2634    Vistara      24/03/2019  Banglore   New Delhi              BLR → DEL
# 5470    Vistara      24/03/2019  Banglore   New Delhi              BLR → DEL
#
# ...

# %% [markdown]
# ### 3 OBSERVATIONS
#
# - The type of Date_of_Journey, Dep_Time and Arrival_Time should be changed to datetime
#   - The type of Duration and Total_Stops is mixed. It should be numeric type.
#   - There're 220 duplicates. These should be removed.

# %% [markdown]
# ### 4 DETAIL ANALYSIS

# %% [markdown]
# ### Airline

# %%
flights.Airline
# Out:
# 0             IndiGo
# 1          Air India
# 2        Jet Airways
# 3             IndiGo
# 4             IndiGo
#             ...
# 10678       Air Asia
# 10679      Air India
# 10680    Jet Airways
# 10681        Vistara
# 10682      Air India
# Name: Airline, Length: 10683, dtype: str

# %%
flights.Airline.unique()
# Out:
# <ArrowStringArray>
# [                           'IndiGo',                         'Air India',
#                        'Jet Airways',                          'SpiceJet',
#                  'Multiple carriers',                             'GoAir',
#                            'Vistara',                          'Air Asia',
#            'Vistara Premium economy',              'Jet Airways Business',
#  'Multiple carriers Premium economy',                            'Trujet']
# Length: 12, dtype: str

# %% [markdown]
# Some of the entries have inconsistent/inaccurate values
# Like we have vistara and vistara premium economy so we do some cleaning

# %%
(
    flights
    .Airline
    .str.replace(" Premium economy","")
    .str.replace(" Business", "")
    .str.title()
    .unique()
)
# Out:
# <ArrowStringArray>
# [           'Indigo',         'Air India',       'Jet Airways',
#           'Spicejet', 'Multiple Carriers',             'Goair',
#            'Vistara',          'Air Asia',            'Trujet']
# Length: 9, dtype: str

# %% [markdown]
# ### Date Of Journey

# %%
flights.Date_of_Journey
# Out:
# 0        24/03/2019
# 1         1/05/2019
# 2         9/06/2019
# 3        12/05/2019
# 4        01/03/2019
#             ...
# 10678     9/04/2019
# 10679    27/04/2019
# 10680    27/04/2019
# 10681    01/03/2019
# 10682     9/05/2019
# Name: Date_of_Journey, Length: 10683, dtype: str

# %%
pd.to_datetime(flights.Date_of_Journey,dayfirst=True)
# Out:
# 0       2019-03-24
# 1       2019-05-01
# 2       2019-06-09
# 3       2019-05-12
# 4       2019-03-01
#            ...
# 10678   2019-04-09
# 10679   2019-04-27
# 10680   2019-04-27
# 10681   2019-03-01
# 10682   2019-05-09
# Name: Date_of_Journey, Length: 10683, dtype: datetime64[us]

# %% [markdown]
# ### Source

# %%
flights.Source.unique()
# Out:
# <ArrowStringArray>
# ['Banglore', 'Kolkata', 'Delhi', 'Chennai', 'Mumbai']
# Length: 5, dtype: str

# %% [markdown]
# ### Destination

# %%
flights.Destination.unique()
# Out:
# <ArrowStringArray>
# ['New Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Delhi', 'Hyderabad']
# Length: 6, dtype: str

# %% [markdown]
# ### Departure Time

# %%
flights.Dep_Time
# Out:
# 0        22:20
# 1        05:50
# 2        09:25
# 3        18:05
# 4        16:50
#          ...
# 10678    19:55
# 10679    20:45
# 10680    08:20
# 10681    11:30
# 10682    10:55
# Name: Dep_Time, Length: 10683, dtype: str

# %%
(
	flights
	.Dep_Time
	.loc[lambda ser: ser.str.contains("[^0-9:]")]
)
# Out:
# Series([], Name: Dep_Time, dtype: str)

# %% [markdown]
# The above code checks if any departure has values other than 0 to 9 and :

# %%
pd.to_datetime(flights.Dep_Time).dt.time
# Out:
# C:\Users\lalith Kumar\AppData\Local\Temp\ipykernel_23260\1056054517.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(flights.Dep_Time).dt.time
# 0        22:20:00
# 1        05:50:00
# 2        09:25:00
# 3        18:05:00
# 4        16:50:00
#            ...
# 10678    19:55:00
# 10679    20:45:00
# 10680    08:20:00
# 10681    11:30:00
# 10682    10:55:00
# Name: Dep_Time, Length: 10683, dtype: object

# %% [markdown]
# ### Arrival Time

# %%
(
    flights.
    Arrival_Time
    .loc[lambda ser: ser.str.contains("[^0-9:]")]
)
# Out:
# 0        01:10 22 Mar
# 2        04:25 10 Jun
# 6        10:25 13 Mar
# 7        05:05 02 Mar
# 8        10:25 13 Mar
#              ...
# 10666    19:00 13 Jun
# 10667    20:20 13 Mar
# 10672    19:00 28 Jun
# 10673    04:25 28 May
# 10674    21:20 13 Mar
# Name: Arrival_Time, Length: 4335, dtype: str

# %%
(
    flights.
    Arrival_Time
    .loc[lambda ser: ser.str.contains("[^0-9:]")].
    str.split(" ",n=1)
    .str.get(1)
)
# Out:
# 0        22 Mar
# 2        10 Jun
# 6        13 Mar
# 7        02 Mar
# 8        13 Mar
#           ...
# 10666    13 Jun
# 10667    13 Mar
# 10672    28 Jun
# 10673    28 May
# 10674    13 Mar
# Name: Arrival_Time, Length: 4335, dtype: object

# %% [markdown]
# ### Duration

# %%
flights.Duration
# Out:
# 0        2h 50m
# 1        7h 25m
# 2           19h
# 3        5h 25m
# 4        4h 45m
#           ...
# 10678    2h 30m
# 10679    2h 35m
# 10680        3h
# 10681    2h 40m
# 10682    8h 20m
# Name: Duration, Length: 10683, dtype: str

# %%
(
    flights
    .Duration
    .loc[lambda ser:~ser.str.contains("m")]
)
# Out:
# 2        19h
# 18       23h
# 33       22h
# 44       12h
# 53        3h
#         ...
# 10591    23h
# 10638    14h
# 10639    38h
# 10673    15h
# 10680     3h
# Name: Duration, Length: 1031, dtype: str

# %%
(
    flights
    .Duration
    .loc[lambda ser:~ser.str.contains("h")]
)
# Out:
# 6474    5m
# Name: Duration, dtype: str

# %%
flights.iloc[[6474]]
# Out:
#         Airline Date_of_Journey  Source Destination                  Route  \
# 6474  Air India       6/03/2019  Mumbai   Hyderabad  BOM → GOI → PNQ → HYD
#
#      Dep_Time Arrival_Time Duration Total_Stops Additional_Info  Price
# 6474    16:50        16:55       5m     2 stops         No info  17327

# %% [markdown]
# The observation indexed 6474 has duration of 5 minutes. This is clearly wrong. Will delete this observation.

# %%
(flights
.Duration
.drop(index=6474)
.str.split(" ",expand=True)
 .set_axis(["hour","minute"],axis=1)
 .assign(
     hour=lambda df_:(
         df_.
         hour
         .str.replace("h","")
         .astype(int)
         .mul(60)
     ),
     minute=lambda df_:(
         df_
         .minute
         .str.replace("m","")
         .fillna("0")
         .astype(int)
     )
 )
 .sum(axis=1)

 


)
# Out:
# 0         170
# 1         445
# 2        1140
# 3         325
# 4         285
#          ...
# 10678     150
# 10679     155
# 10680     180
# 10681     160
# 10682     500
# Length: 10682, dtype: int64

# %% [markdown]
# ### Total Stops

# %%
flights.Total_Stops
# Out:
# 0        non-stop
# 1         2 stops
# 2         2 stops
# 3          1 stop
# 4          1 stop
#            ...
# 10678    non-stop
# 10679    non-stop
# 10680    non-stop
# 10681    non-stop
# 10682     2 stops
# Name: Total_Stops, Length: 10683, dtype: str

# %%
(flights
.Total_Stops
.replace("non-stop","0")
 .str.replace(" stops?","",regex=True)
 .pipe(lambda ser: pd.to_numeric(ser))
)
# Out:
# <ArrowStringArray>
# ['0', '2', '1', '3', nan, '4']
# Length: 6, dtype: str

# %% [markdown]
# ### additional_info

# %%
flights.Additional_Info.unique()

# %% [markdown]
# ### 5 CLEANING OPERATIONS

# %%
def convert_to_minutes(ser):
	return (
		ser
		.str.split(" ", expand=True)
		.set_axis(["hour", "minute"], axis=1)
		.assign(
			hour=lambda df_: (
				df_
				.hour
				.str.replace("h", "")
				.astype(int)
				.mul(60)
			),
			minute=lambda df_: (
				df_
				.minute
				.str.replace("m", "")
				.fillna("0")
				.astype(int)
			)
		)
		.sum(axis=1)
	)

# %%
def clean_data(df):
    return (
        df
        .drop(index=[6474])
        .assign(**{
			col: df[col].str.strip()
			for col in df.select_dtypes(include="str").columns
		})
        .rename(columns=str.lower)
        .assign(
            airline=lambda df_:(
                df_
                .airline
                .str.replace(" Premium economy","")
                .str.replace(" Business", "")
                .str.title()
             
            ),
             date_of_journey=lambda df_:  pd.to_datetime(df_.date_of_journey,dayfirst=True),
             dep_time=lambda df_:pd.to_datetime(df_.dep_time).dt.time,
             arrival_time=lambda df_:pd.to_datetime(df_.arrival_time).dt.time,
            duration=lambda df_: df_.duration.pipe(convert_to_minutes),
            total_stops=lambda df_: (
				df_
				.total_stops
				.replace("non-stop", "0")
				.str.replace(" stops?", "", regex=True)
				.pipe(lambda ser: pd.to_numeric(ser))
			),
            additional_info=lambda df_: df_.additional_info.replace("No info", "No Info")
            
           
            
          
        )
        .drop(columns="route")
    )

# %% [markdown]
# ### Code Understanding
# The above assign method takes each col which is string bt that for loop and strips it ,i mean it removes extra spaces in the features
# of that columns

# %%
flights_cleaned=clean_data(flights)
flights_cleaned
# Out:
# C:\Users\lalith Kumar\AppData\Local\Temp\ipykernel_5044\1759512282.py:20: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dep_time=lambda df_:pd.to_datetime(df_.dep_time).dt.time,
# C:\Users\lalith Kumar\AppData\Local\Temp\ipykernel_5044\1759512282.py:21: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   arrival_time=lambda df_:pd.to_datetime(df_.arrival_time).dt.time,
#            airline date_of_journey    source destination  dep_time  \
# 0           Indigo      2019-03-24  Banglore   New Delhi  22:20:00
# 1        Air India      2019-05-01   Kolkata    Banglore  05:50:00
# 2      Jet Airways      2019-06-09     Delhi      Cochin  09:25:00
# 3           Indigo      2019-05-12   Kolkata    Banglore  18:05:00
# ...

# %% [markdown]
# ### 6 Split the Data

# %% [markdown]
# ## EXPORT THE SUBSET
